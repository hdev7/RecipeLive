# %% [markdown]
# ### Image Classification using MobileNetV2 model
# - Transfer learning from mobilenetV2 model
# - Add dense layers to the mobilenetV2 model
# - Train the model with our data
# - Validate the model with model
# - Examine the model overall performance
# - Save the trained models and features to be used in the web application for real time prediction

# %%
''' Modular programming concepts. I like to put chunk of my code in python scripts and would like to import it from there. 
 Major heavy lifting should always be done in the scripts which should be abstracted and things should happen at the call
 of a function or an API'''
from kerasUtil import *
from miscScript import *
from recipeScript import *
# Out:
# Using TensorFlow backend.
# c:\users\heman\.conda\envs\tensor\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\heman\Documents\DS\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ####  Get the pre-trained mobilenetV2 model - transfer learning

# %%
# Extract features from images and save 
save_bottleneck_features('monet')
# Out:
# Found 2030 images belonging to 10 classes.
# 2030
# {'baby carrot': 0, 'bean sprouts': 1, 'bell pepper': 2, 'broccoli': 3, 'cabbage': 4, 'cauliflower': 5, 'eggplant': 6, 'kale': 7, 'spinach': 8, 'tomato': 9}
# 10
# c:\users\heman\.conda\envs\tensor\lib\site-packages\PIL\Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Found 992 images belonging to 10 classes.
# 'monet'

# %%
# train the top layer of MobileNet_v2 model
train_top_model('monet')
# Out:
# Found 2030 images belonging to 10 classes.
# Found 992 images belonging to 10 classes.
# (2030, 7, 7, 1280)
# Train on 2030 samples, validate on 992 samples
# Epoch 1/35
# ...
